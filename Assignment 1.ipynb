# %% [markdown]
# ## Explain the Key features of Python that make it a popular choice for programming.
#
# 1.Python is versatile and flexible- Python is a general purpose language,which means it can be used to create a wide variety of         applications.
# 2.Python is simple and easy to learn- Python's simple and clean syntax makes it an ideal language for beginners.its commands are English-   based,and its straightforward layout helps new programmers understand code easily.This simplicity also makes Python suitable for rapid development and prototyping.
# 3.Python is open source- Python's open source nature has led to the development of vast ecosystem of libraries and frameworks.whether you need tools for web development(django,flask),data analysis(pandas,Numpy),Machine Learning(Teansorflow,scikit-learn),or any other task,Python has a library for it.
# 4.Python has strong community support- Python boasts a large and active community of developers,contributing to its continues improvement.This community support means that there are countless tutorials,forums,and documentation available to help new comers and experienced developers alike.
# 5.Python is used Everywhere- Python's widespread use in various industries makes it a valuable skill for developers. Companies across the globe, from tech giants like Google and Facebook to financial institutions like JP Morgan Chase, rely on Python for their technological solutions.

# %% [markdown]
# ## Describe the role of Pre defined keywords in python and provide examples of how they are used in a program.
#
# A keyword refers to a predefined word that python reserves for working programs that have a specific meaning. A programmer cannot use
# a keyword anywhere and everywhere. There are applicable restrictions for the usage of keywords.
#   example-Print("hello world")
#             >>hello world

# %% [markdown]
# ## Compare the contrast mutable and immutable objects in python with examples.
#
# Data types in Python are categorized into mutable and immutable data types. Mutable data types are those whose values can be changed, whereas immutable data types are ones in which the values can’t be changed.
# Python is one of the most popular programming languages that offers a rich set of data types. A Python data type defines the type of data stored in a variable. Unlike Java, C, and C++ in Python, we do not specify the variable’s data type explicitly. The data type in Python is automatically detected when the value is stored in the variable.
#
# Python data type is categorized into two types:
#
# Mutable Data Type – A mutable data type is one whose values can be changed.
# Example: List, Diction and set.
#  Set
# Immutable Data Type – An immutable data type is one in which the values can’t be changed or altered.
# Example: String and. Tuples

# %% [markdown]
# ## Discuss the different types of Operators in python and provide examples of how they are used.
#
# In Python, operators are special symbols that perform operations on variables and values. They can be classified into several categories:
#
# 1. Arithmetic Operators
# These operators perform basic mathematical operations.
#
# Addition (+)
#       a = 10
# b = 5
# result = a + b  # result is
# Subtraction (-)
#       result = a - b  # result is 5
# Multiplication (*)
#       result = a * b  # result is 50
# Division (/)
#        result = a / b  # result is 2.0
# Floor Division (//)
#         result = a // b  # result is 2
# Modulus (%)
#        result = a % b  # result is 0
# Exponentiation (**)
#        result = a ** 2  # result is 100
# In Python, operators are special symbols that perform operations on variables and values. They can be classified into several categories:
#
# 1. Arithmetic Operators
# These operators perform basic mathematical operations.
#
# Addition (+)
#
# python
# Copy code
# a = 10
# b = 5
# result = a + b  # result is 15
# Subtraction (-)
#
# python
# Copy code
# result = a - b  # result is 5
# Multiplication (*)
#
# python
# Copy code
# result = a * b  # result is 50
# Division (/)
#
# python
# Copy code
# result = a / b  # result is 2.0
# Floor Division (//)
#
# python
# Copy code
# result = a // b  # result is 2
# Modulus (%)
#
# python
# Copy code
# result = a % b  # result is 0
# Exponentiation (**)
#
# python
# Copy code
# result = a ** 2  # result is 100
# 2. Comparison Operators
# These operators compare values and return a Boolean result.
#
# Equal to (==)
#        result = (a == b)  # result is False
# Not equal to (!=)
#        result = (a != b)  # result is True
# Greater than (>)
#        result = (a > b)  # result is True
# Less than (<)
#        result = (a < b)  # result is False
# Greater than or equal to (>=)
#        result = (a >= b)  # result is True
# Less than or equal to (<=)
#         result = (a <= b)  # result is False
# 3. Logical Operators
# These operators combine conditional statements.
#
# And (and)
#      result = (a > 0 and b > 0)  # result is True
# Or (or)
#     result = (a < 0 or b < 0)  # result is False
# Not (not)
#     result = not (a > b)  # result is True
# 4. Bitwise Operators
# These operators perform operations on binary representations of integers.
#
# And (&)
#      result = a & b  # result is 0 (in binary: 1010 & 0101 = 0000)
# Or (|)
#      result = a | b  # result is 15 (in binary: 1010 | 0101 = 1111)
# XOR (^)
#      result = a ^ b  # result is 15 (in binary: 1010 ^ 0101 = 1111)
# Left Shift (<<)
#      result = a << 1  # result is 20 (in binary: 1010 becomes 10100)
# Right Shift (>>)
#      result = a >> 1  # result is 5 (in binary: 1010 becomes 0101)
# 5. Assignment Operators
# These operators assign values to variables.
#
# Simple Assignment (=)
#     a = 10
# Add and Assign (+=)
#    a += 5  # a becomes 15
# Subtract and Assign (-=)
#    a -= 5  # a becomes 10
# Multiply and Assign (*=)
#    a *= 2  # a becomes 20
# Divide and Assign (/=)
#    a /= 2  # a becomes 10.0
# 6. Identity Operators
# These operators check if two variables point to the same object.
#
# Is (is)
#    result = (a is b)  # result is False
# Is Not (is not)
#    result = (a is not b)  # result is True
# 7. Membership Operators
# These operators test for membership in sequences.
#
# In (in)
#     my_list = [1, 2, 3]
# result = (2 in my_list)  # result is TrueNot In (not in)
#     result = (4 not in my_list)  # result is True
# Conclusion
# These operators form the core functionality of Python, enabling a wide range of computations and logical operations. Understanding how to use them effectively is essential for programming in Python.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 15

# %% [markdown]
# ## Explain the concept of type casting in python with examples.
#
# Type casting in Python is the process of converting a variable from one data type to another. This is useful when you need to perform operations that require specific types or when you want to ensure compatibility between different data types. Python provides several built-in functions for type casting.
#
# Implicit Type Casting: This happens automatically when Python converts one data type to another without explicit instruction. For example, when you add an integer and a float, Python will automatically convert the integer to a float.
#      a = 5        # int
# b = 2.5      # float
# result = a + b  # a is implicitly converted to float
# print(result)   # Output: 7.Explicit Type Casting: This is done manually using functions like int(), float(), str(), etc. You specify the type you want to convert to.
#       # Converting a float to an integer
# a = 5.7
# b = int(a)  # Explicitly converting float to int
# print(b)    # Output: 5
#
# # Converting an integer to a string
# c = 10
# d = str(c)  # Explicitly converting int to string
# print(d)    # Outpu
# Examples of Type Casting
# Integer to Float
#      num_int = 42
# num_float = float(num_int)
# print(num_float)  # Output: 42.
# Float to Integer
#    num_float = 3.99
# num_int = int(num_float)
# print(num_int)  # Output: 3String to Integer
#    num_str = "123"
# num_int = int(num_str)
# print(num_int)  # Output: 12
# String to Float
#     num_str = "45.67"
# num_float = float(num_str)
# print(num_float)  # Output: 45.6
# Combining Different Types
#
# You can also use type casting to combine different types, ensuring they are compatible:
#       a = "5"
# b = 2
# result = int(a) + b  # Convert string to int before adding
# print(result)  # Output: 7
# 7
# 3
#
# 0
# t: '10'
# 5

# %% [markdown]
# ## How do conditional statements work in Python?Illustrate with examples.
#
# If the condition is True, the code block indented below the if statement will be executed. If the condition is False, the code block will be skipped. Here's an example of how to use an if statement to check if a number is positive: num = 5 if num > 0: print("The number is positive.")

# %% [markdown]
# ##  Describe the different types of Loops in Python and their use cases with example.
#
# Type of Loops
#
# For Loop. A for loop in Python is used to iterate over a sequence (list, tuple, set, dictionary, and string). Flowchart: ..
#   n = 4
# for i in range(0, n):
#     print(i)
#
# While Loop. The while loop is used to execute a set of statements as long as a condition is true.
#
# count = 0
# while (count < 3):
#     count = count + 1
#     print("Hello G
# ek")
# .
# Nested Loop. If a loop exists inside the body of another loop, it is called a nest
#  from __future__ import print_function
# for i in range(1, 5):
#     for j in range(i):
#         print(i, end=' ')
#     print()ed loop.
